# %%
from sss.datasets.oai import load_dataset, parse_fn_restore, normalize_image
from sss.augmentation.dual_transform import random_mono_jitter
from sss.augmentation.base import random_crop_with_resize, random_brightness, random_gamma, random_gaussian_noise, gaussian_blur
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
train_ds, val_ds = load_dataset(
            batch_size=64,
            dataset_dir='gs://oai-challenge-dataset/tfrecords',
            training_mode='finetune',
            fraction_data=1.0,
            multi_class=False,
            add_background=False,
            normalize=True,
            buffer_size=500,
            parse_fn=parse_fn_restore)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-34-b6785904cee4> in <module>
#       8             normalize=True,
#       9             buffer_size=500,
# ---> 10             parse_fn=parse_fn_restore)
#
# ~/Self-Supervised-Segmentation/sss/datasets/oai.py in load_dataset(batch_size, dataset_dir, training_mode, fraction_data, multi_class, add_background, normalize, permutations, buffer_size, parse_fn)
#     386         normalize=normalize,
#     387         permutations=permutations,
# --> 388         parse_fn=parse_fn
#     389         )
#     390
#
# ~/Self-Supervised-Segmentation/sss/datasets/oai.py in read_tfrecord(tfrecords_dir, batch_size, buffer_size, is_training, training_mode, fraction_data, multi_class, add_background, normalize, permutations, parse_fn)
#     324             num_parallel_calls=AUTOTUNE)
#     325     elif parse_fn == parse_fn_restore:
# --> 326         assert permutations is not None, 'Permutations cannot be None'
#     327         dataset = dataset.map(
#     328             partial(
#
# AssertionError: Permutations cannot be None

# %%
for step, (image, seg, shuffled) in enumerate(train_ds):
    for i in range(image.shape[0]):
        plt.imshow(image[i,:,:,0], cmap='gray')
        plt.show()
        plt.imshow(image[i,:,:,1], cmap='gray')
        plt.show()
    if step == 0:
        break

# %%
train_ds, val_ds = load_dataset(
            batch_size=64,
            dataset_dir='gs://oai-challenge-dataset/tfrecords',
            training_mode='finetune',
            fraction_data=1.0,
            multi_class=False,
            add_background=False,
            normalize=False,
            buffer_size=500)

# %%
for step, (image, seg) in enumerate(train_ds):
#     image1, image2 = get_preprocess_fn(image[0,...], True, 288)
    sample_img = image[0,:,:,:]
    sample_seg = seg[0,:,:,:]
    plt.imshow(image[0,:,:,0], cmap='gray')
    plt.show()
#     plt.imshow(image1[0,:,:,0], cmap='gray')
#     plt.imshow(image2[0,:,:,0], cmap='gray')
    plt.imshow(seg[0,:,:,0], cmap='gray')
    plt.show()
    if step == 0:
        break

# %%
# sample_img = normalize_image(sample_img)
sample_img = sample_img / tf.math.reduce_max(sample_img)
sample_img = tf.clip_by_value(sample_img, 0., 1.)
print(sample_img.shape, sample_seg.shape)
# Out:
# (288, 288, 1) (288, 288, 1)

# %%
plt.hist(sample_img[...,0])
plt.show()

# %%
image_bright = tf.clip_by_value(tf.image.adjust_brightness(sample_img, 0.5), 0., 1.)
image_contrast = tf.clip_by_value(tf.image.adjust_contrast(sample_img, 2.0), 0., 1.)
image_gamma = tf.clip_by_value(tf.image.adjust_gamma(sample_img, 0.2), 0., 1.)
image_noise = tf.clip_by_value(random_gaussian_noise(sample_img, 0.5), 0., 1.)
image_blur = gaussian_blur(sample_img, 28.8, 2.0, padding='SAME')
image_crop = random_crop_with_resize(sample_img, [288,288], (0.2, 0.5))
image_flip = tf.image.flip_left_right(sample_img)

# %%
plt.figure(figsize=(8,4))
plt.subplot(2, 4, 1)
plt.imshow(sample_img[...,0], cmap='gray')
plt.title('Original')
plt.subplot(2, 4, 2)
plt.imshow(image_bright[...,0], cmap='gray')
plt.title('Brightness')
plt.subplot(2, 4, 3)
plt.imshow(image_contrast[...,0], cmap='gray')
plt.title('Contrast')
plt.subplot(2, 4, 4)
plt.imshow(image_gamma[...,0], cmap='gray')
plt.title('Gamma')
plt.subplot(2, 4, 5)
plt.imshow(image_noise[...,0], cmap='gray')
plt.title('Gaussian Noise')
plt.subplot(2, 4, 6)
plt.imshow(image_blur[...,0], cmap='gray')
plt.title('Gaussian Blur')
plt.subplot(2, 4, 7)
plt.imshow(image_crop[...,0],cmap='gray')
plt.title('Crop and Resize')
plt.subplot(2, 4, 8)
plt.imshow(image_flip[...,0],cmap='gray')
plt.title('Flip')
plt.tight_layout()
plt.savefig('augmentation_examples.png')
