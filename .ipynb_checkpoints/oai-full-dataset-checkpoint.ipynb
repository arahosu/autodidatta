# %%
import tensorflow_io as tfio
from google.cloud import storage
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.4.2-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 11.9 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.16 in /home/User/.local/lib/python3.7/site-packages (from matplotlib) (1.19.5)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.3.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 53.9 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /home/User/.local/lib/python3.7/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/User/.local/lib/python3.7/site-packages (from matplotlib) (2.8.2)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 53.2 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: six in /home/User/.local/lib/python3.7/site-packages (from cycler>=0.10->matplotlib) (1.15.0)
# Installing collected packages: pillow, kiwisolver, cycler, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.3.1 matplotlib-3.4.2 pillow-8.3.1

# %%
storage_client = storage.Client()
file_list = []
prefix_list = ['00m', '12m', '18m', '24m', '30m', '36m', '48m', '72m', '96m']

for item in prefix_list:
    print('loading ' + item)
    prefix = 'data/' + str(item)
    blobs = storage_client.list_blobs('oai-challenge-dataset', prefix=prefix)

    for blob in blobs:
        file_name = 'gs://oai-challenge-dataset/' + str(blob.name)
        file_list.append(file_name)
    
    print(len(file_list))

print(len(file_list))
# Out:
# loading 00m
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_175340/568126971.py in <module>
#       8     blobs = storage_client.list_blobs('oai-challenge-dataset', prefix=prefix)
#       9
# ---> 10     for blob in blobs:
#      11         file_name = 'gs://oai-challenge-dataset/' + str(blob.name)
#      12         file_list.append(file_name)
#
# /usr/local/lib/python3.8/dist-packages/google/api_core/page_iterator.py in _items_iter(self)
#     210     def _items_iter(self):
#     211         """Iterator for each item returned."""
# --> 212         for page in self._page_iter(increment=False):
#     213             for item in page:
#     214                 self.num_results += 1
#
# /usr/local/lib/python3.8/dist-packages/google/api_core/page_iterator.py in _page_iter(self, increment)
#     247                 self.num_results += page.num_items
#     248             yield page
# --> 249             page = self._next_page()
#     250
#     251     @abc.abstractmethod
#
# /usr/local/lib/python3.8/dist-packages/google/api_core/page_iterator.py in _next_page(self)
#     367         """
#     368         if self._has_next_page():
# --> 369             response = self._get_next_page_response()
#     370             items = response.get(self._items_key, ())
#     371             page = Page(self, items, self.item_to_value, raw_page=response)
#
# /usr/local/lib/python3.8/dist-packages/google/api_core/page_iterator.py in _get_next_page_response(self)
#     416         params = self._get_query_params()
#     417         if self._HTTP_METHOD == "GET":
# --> 418             return self.api_request(
#     419                 method=self._HTTP_METHOD, path=self.path, query_params=params
#     420             )
#
# ~/.local/lib/python3.8/site-packages/google/cloud/storage/_http.py in api_request(self, *args, **kwargs)
#      76             if retry:
#      77                 call = retry(call)
# ---> 78         return call()
#
# /usr/local/lib/python3.8/dist-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     283                 self._initial, self._maximum, multiplier=self._multiplier
#     284             )
# --> 285             return retry_target(
#     286                 target,
#     287                 self._predicate,
#
# /usr/local/lib/python3.8/dist-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     186     for sleep in sleep_generator:
#     187         try:
# --> 188             return target()
#     189
#     190         # pylint: disable=broad-except
#
# ~/.local/lib/python3.8/site-packages/google/cloud/_http.py in api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout)
#     471             content_type = "application/json"
#     472
# --> 473         response = self._make_request(
#     474             method=method,
#     475             url=url,
#
# ~/.local/lib/python3.8/site-packages/google/cloud/_http.py in _make_request(self, method, url, data, content_type, headers, target_object, timeout)
#     335         headers["User-Agent"] = self.user_agent
#     336
# --> 337         return self._do_request(
#     338             method, url, headers, data, target_object, timeout=timeout
#     339         )
#
# ~/.local/lib/python3.8/site-packages/google/cloud/_http.py in _do_request(self, method, url, headers, data, target_object, timeout)
#     373         :returns: The HTTP response.
#     374         """
# --> 375         return self.http.request(
#     376             url=url, method=method, headers=headers, data=data, timeout=timeout
#     377         )
#
# /usr/local/lib/python3.8/dist-packages/google/auth/transport/requests.py in request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     480
#     481         with TimeoutGuard(remaining_time) as guard:
# --> 482             response = super(AuthorizedSession, self).request(
#     483                 method,
#     484                 url,
#
# /usr/local/lib/python3.8/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# /usr/local/lib/python3.8/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     695
#     696         if not stream:
# --> 697             r.content
#     698
#     699         return r
#
# /usr/local/lib/python3.8/dist-packages/requests/models.py in content(self)
#     829                 self._content = None
#     830             else:
# --> 831                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     832
#     833         self._content_consumed = True
#
# /usr/local/lib/python3.8/dist-packages/requests/models.py in generate()
#     751             if hasattr(self.raw, 'stream'):
#     752                 try:
# --> 753                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     754                         yield chunk
#     755                 except ProtocolError as e:
#
# /usr/local/lib/python3.8/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#     574         else:
#     575             while not is_fp_closed(self._fp):
# --> 576                 data = self.read(amt=amt, decode_content=decode_content)
#     577
#     578                 if data:
#
# /usr/local/lib/python3.8/dist-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# /usr/lib/python3.8/http/client.py in read(self, amt)
#     453             # Amount is given, implement using readinto
#     454             b = bytearray(amt)
# --> 455             n = self.readinto(b)
#     456             return memoryview(b)[:n].tobytes()
#     457         else:
#
# /usr/lib/python3.8/http/client.py in readinto(self, b)
#     497         # connection, and the user is reading more bytes than will be provided
#     498         # (for example, reading in 1k chunks)
# --> 499         n = self.fp.readinto(b)
#     500         if not n and b:
#     501             # Ideally, we would raise IncompleteRead if the content-length
#
# /usr/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /usr/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
with open("dicom_files.txt", "w") as output:
    for idx, item in enumerate(file_list):
        if idx % 10000 == 0:
            print('{} out of {}'.format(idx+1, len(file_list)))
        output.write('{}\n'.format(item))
# Out:
# 1 out of 7786206
# 10001 out of 7786206
# 20001 out of 7786206
# 30001 out of 7786206
# 40001 out of 7786206
# 50001 out of 7786206
# 60001 out of 7786206
# 70001 out of 7786206
# 80001 out of 7786206
# 90001 out of 7786206
# 100001 out of 7786206
# 110001 out of 7786206
# 120001 out of 7786206
# 130001 out of 7786206
# 140001 out of 7786206
# 150001 out of 7786206
# 160001 out of 7786206
# 170001 out of 7786206
# 180001 out of 7786206
# 190001 out of 7786206
# 200001 out of 7786206
# 210001 out of 7786206
# 220001 out of 7786206
# 230001 out of 7786206
# 240001 out of 7786206
# 250001 out of 7786206
# 260001 out of 7786206
# 270001 out of 7786206
# 280001 out of 7786206
# 290001 out of 7786206
# 300001 out of 7786206
# 310001 out of 7786206
# 320001 out of 7786206
# 330001 out of 7786206
# 340001 out of 7786206
# 350001 out of 7786206
# 360001 out of 7786206
# 370001 out of 7786206
# 380001 out of 7786206
# 390001 out of 7786206
# 400001 out of 7786206
# 410001 out of 7786206
# 420001 out of 7786206
# 430001 out of 7786206
# 440001 out of 7786206
# 450001 out of 7786206
# 460001 out of 7786206
# 470001 out of 7786206
# 480001 out of 7786206
# 490001 out of 7786206
# 500001 out of 7786206
# 510001 out of 7786206
# 520001 out of 7786206
# 530001 out of 7786206
# 540001 out of 7786206
# 550001 out of 7786206
# 560001 out of 7786206
# 570001 out of 7786206
# 580001 out of 7786206
# 590001 out of 7786206
# 600001 out of 7786206
# 610001 out of 7786206
# 620001 out of 7786206
# 630001 out of 7786206
# 640001 out of 7786206
# 650001 out of 7786206
# 660001 out of 7786206
# 670001 out of 7786206
# 680001 out of 7786206
# 690001 out of 7786206
# 700001 out of 7786206
# 710001 out of 7786206
# 720001 out of 7786206
# 730001 out of 7786206
# 740001 out of 7786206
# 750001 out of 7786206
# 760001 out of 7786206
# 770001 out of 7786206
# 780001 out of 7786206
# 790001 out of 7786206
# 800001 out of 7786206
# 810001 out of 7786206
# 820001 out of 7786206
# 830001 out of 7786206
# 840001 out of 7786206
# 850001 out of 7786206
# 860001 out of 7786206
# 870001 out of 7786206
# 7040001 out of 7786206
# 7050001 out of 7786206
# 7060001 out of 7786206
# 7070001 out of 7786206
# 7080001 out of 7786206
# 7090001 out of 7786206
# 7100001 out of 7786206
# 7110001 out of 7786206
# 7120001 out of 7786206
# 7130001 out of 7786206
# 7140001 out of 7786206
# 7150001 out of 7786206
# 7160001 out of 7786206
# 7170001 out of 7786206
# 7180001 out of 7786206
# 7190001 out of 7786206
# 7200001 out of 7786206
# 7210001 out of 7786206
# 7220001 out of 7786206
# 7230001 out of 7786206
# 7240001 out of 7786206
# 7250001 out of 7786206
# 7260001 out of 7786206
# 7270001 out of 7786206
# 7280001 out of 7786206
# 7290001 out of 7786206
# 7300001 out of 7786206
# 7310001 out of 7786206
# 7320001 out of 7786206
# 7330001 out of 7786206
# 7340001 out of 7786206
# 7350001 out of 7786206
# 7360001 out of 7786206
# 7370001 out of 7786206
# 7380001 out of 7786206
# 7390001 out of 7786206
# 7400001 out of 7786206
# 7410001 out of 7786206
# 7420001 out of 7786206
# 7430001 out of 7786206
# 7440001 out of 7786206
# 7450001 out of 7786206
# 7460001 out of 7786206
# 7470001 out of 7786206
# 7480001 out of 7786206
# 7490001 out of 7786206
# 7500001 out of 7786206
# 7510001 out of 7786206
# 7520001 out of 7786206
# 7530001 out of 7786206
# 7540001 out of 7786206
# 7550001 out of 7786206
# 7560001 out of 7786206
# 7570001 out of 7786206
# 7580001 out of 7786206
# 7590001 out of 7786206
# 7600001 out of 7786206
# 7610001 out of 7786206
# 7620001 out of 7786206
# 7630001 out of 7786206
# 7640001 out of 7786206
# 7650001 out of 7786206
# 7660001 out of 7786206
# 7670001 out of 7786206
# 7680001 out of 7786206
# 7690001 out of 7786206
# 7700001 out of 7786206
# 7710001 out of 7786206
# 7720001 out of 7786206
# 7730001 out of 7786206
# 7740001 out of 7786206
# 7750001 out of 7786206
# 7760001 out of 7786206
# 7770001 out of 7786206
# 7780001 out of 7786206

# %%
text_file = open("dicom_files.txt", "r")
lines = text_file.readlines()
filelist = []
print(len(lines))
for filename in lines:
    line = filename[:-1]
    filelist.append(line)

for f in filelist:
    image_bytes = tf.io.read_file(f)
    # image = tfio.image.decode_dicom_image(image_bytes, dtype=tf.uint16)
    data = tfio.image.decode_dicom_data(image_bytes, tags=["[0x0020,0x000E]"])
    print(data)
    break
# Out:
# 7786206
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /tmp/ipykernel_21350/104484226.py in <module>
#      10     image_bytes = tf.io.read_file(f)
#      11     # image = tfio.image.decode_dicom_image(image_bytes, dtype=tf.uint16)
# ---> 12     data = tfio.image.decode_dicom_data(image_bytes, tags=["[0x0008,0x1115][0][0x0008,0x1140][0][0x0008,0x1155]"], name=None)
#      13     print(data)
#      14     break
#
# ~/.local/lib/python3.7/site-packages/tensorflow_io/python/ops/dicom_ops.py in decode_dicom_data(contents, tags, name)
#     130         only the zeroth element will be returned as a string.
#     131     """
# --> 132     return core_ops.io_decode_dicom_data(contents=contents, tags=tags, name=name)
#     133
#     134
#
# <string> in io_decode_dicom_data(contents, tags, name)
#
# <string> in io_decode_dicom_data_eager_fallback(contents, tags, name, ctx)
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# InvalidArgumentError: item findAndGetSequenceItem: Tag not found [Op:IO>DecodeDICOMData]
